# %% [markdown]
# This piece of code is used to filter to generate the data used for training/testing/validation. We assume we already have a dataset with labels containing the images we needed.

# %%
import numpy as np
import pandas as pd
import os
import shutil
import torchvision.transforms as transforms
import PIL

# %%
#mannually add DataFiltered folder
#see Filter.ipynb in the main directory
#Datafiltered folder contains 12 images with 3 classes 11 of which are transformed using augmentations
#in Datafiltered the plural material classes are removed

# %%
pd_label = pd.read_csv('labelsPlural.csv')
pd_label
# Out:
#           filename  item_type    label
# 0     100_i110.png        100  plastic
# 1     100_i120.png        100  plastic
# 2     100_i130.png        100  plastic
# 3     100_i140.png        100  plastic
# 4     100_i150.png        100  plastic
# ...            ...        ...      ...
# 7747  997_i180.png        997  plastic
# 7748  997_i190.png        997  plastic
# 7749  997_i210.png        997  plastic
# 7750  997_i230.png        997  plastic
# 7751  997_i250.png        997  plastic
#
# [7752 rows x 3 columns]

# %%
#frequency of each class
pd_label['label'].value_counts()
max_count = pd_label['label'].value_counts().max()
max_count
# Out:
# 4548

# %%
source_dir = "./DataFilteredPlural/"

# %%
#upsample metal
#sample metal
metal_count = pd_label['label'].value_counts()['metal']
metal = pd_label[pd_label['label'] == 'metal']
metal_sample = metal.sample(max_count-metal_count,replace=True)
metal_sample
# Out:
#           filename  item_type  label
# 2902  433_i230.png        433  metal
# 2585    4_i160.png          4  metal
# 6908  903_i190.png        903  metal
# 3054  453_i170.png        453  metal
# 563   156_i250.png        156  metal
# ...            ...        ...    ...
# 310   131_i230.png        131  metal
# 6459  849_i140.png        849  metal
# 2880  432_i110.png        432  metal
# 7620  986_i110.png        986  metal
# 7430  961_i130.png        961  metal
#
# [3084 rows x 3 columns]

# %%
#apply augmentation
for i in range(len(metal_sample)):
    img = PIL.Image.open(source_dir+metal_sample.iloc[i]['filename'])
    img = transforms.RandAugment()(img)
    item_type = metal_sample.iloc[i]['item_type']
    augname = metal_sample.iloc[i]['filename'][:-4]+'_aug' + str(i) + '.png'
    img.save(source_dir+augname)
    #add to csv
    pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# Out:
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# ...
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)

# %%
#upsample wood,paper
#sample wood,paper
woodpaper_count = pd_label['label'].value_counts()['wood,paper']
woodpaper = pd_label[pd_label['label'] == 'wood,paper']
woodpaper_sample = woodpaper.sample(max_count-woodpaper_count,replace=True)
woodpaper_sample
# Out:
#           filename  item_type       label
# 13    101_i120.png        101  wood,paper
# 1769  306_i160.png        306  wood,paper
# 4086   57_i170.png         57  wood,paper
# 5901   79_i210.png         79  wood,paper
# 5709  768_i210.png        768  wood,paper
# ...            ...        ...         ...
# 6841  899_i120.png        899  wood,paper
# 168   115_i110.png        115  wood,paper
# 4312  600_i150.png        600  wood,paper
# 5169  688_i210.png        688  wood,paper
# 6720  876_i110.png        876  wood,paper
#
# [2808 rows x 3 columns]

# %%
#apply augmentation
for i in range(len(woodpaper_sample)):
    img = PIL.Image.open(source_dir+woodpaper_sample.iloc[i]['filename'])
    img = transforms.RandAugment()(img)
    item_type = woodpaper_sample.iloc[i]['item_type']
    augname = woodpaper_sample.iloc[i]['filename'][:-4]+'_aug' + str(i) + '.png'
    img.save(source_dir+augname)
    #add to csv
    pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# Out:
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)

# %%
#save the upsampled csv
pd_label.to_csv('labels_upsampled.csv',index=False)

# %%
#check the frequency of each class
pd_label['label'].value_counts()
# Out:
# plastic       4548
# wood,paper    4548
# metal         4548
# Name: label, dtype: int64

# %%
#this section augments each class with additional 2000 images per class

# %%
source_dir = "./DataFilteredPlural/"
pd_label = pd.read_csv('./labels_upsampled.csv')
augment_count = 2000

# %%
transforms_erasing = transforms.Compose([transforms.ToTensor(), transforms.RandomErasing(p=0.1, scale=(0.02, 0.33), ratio=(0.3, 1.3), value=0, inplace=False)])

# %%
#sample plastic
plastic_count = pd_label['label'].value_counts()['plastic']
plastic = pd_label[pd_label['label'] == 'plastic']
plastic_sample = plastic.sample(2000,replace=True)
plastic_sample
# Out:
#           filename  item_type    label
# 4917  664_i210.png        664  plastic
# 1853  319_i160.png        319  plastic
# 6218  824_i130.png        824  plastic
# 7745  997_i160.png        997  plastic
# 3167  462_i250.png        462  plastic
# ...            ...        ...      ...
# 6755   88_i250.png         88  plastic
# 3237   47_i210.png         47  plastic
# 4642  632_i230.png        632  plastic
# 6073  809_i120.png        809  plastic
# 7568   98_i190.png         98  plastic
#
# [2000 rows x 3 columns]

# %%
#apply augmentation
for i in range(augment_count):
    img = PIL.Image.open(source_dir+plastic_sample.iloc[i]['filename'])
    img = transforms.RandAugment()(img)
    img = transforms_erasing(img)
    img = transforms.ToPILImage()(img)
    item_type = plastic_sample.iloc[i]['item_type']
    augname = plastic_sample.iloc[i]['filename'][:-4]+'_aug' + str(i) + '.png'
    img.save(source_dir+augname)
    #add to csv
    pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# Out:
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# ...
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\782007253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)

# %%
#sample metal
metal_count = pd_label['label'].value_counts()['metal']
metal = pd_label[pd_label['label'] == 'metal']
metal_sample = metal.sample(2000,replace=True)
metal_sample
# Out:
#                    filename  item_type  label
# 7767     582_i120_aug15.png        582  metal
# 9025   849_i180_aug1273.png        849  metal
# 5987           800_i250.png        800  metal
# 10664  453_i190_aug2912.png        453  metal
# 4509           616_i210.png        616  metal
# ...                     ...        ...    ...
# 9108   860_i250_aug1356.png        860  metal
# 10633  520_i250_aug2881.png        520  metal
# 9925   580_i250_aug2173.png        580  metal
# 976            204_i150.png        204  metal
# 9530   916_i190_aug1778.png        916  metal
#
# [2000 rows x 3 columns]

# %%
#apply augmentation
for i in range(augment_count):
    img = PIL.Image.open(source_dir+metal_sample.iloc[i]['filename'])
    img = transforms.RandAugment()(img)
    img = transforms_erasing(img)
    img = transforms.ToPILImage()(img)
    item_type = metal_sample.iloc[i]['item_type']
    augname = metal_sample.iloc[i]['filename'][:-4]+'_aug_x' + str(i) + '.png'
    img.save(source_dir+augname)
    #add to csv
    pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# Out:
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\2434194722.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)

# %%
#sample wood,paper
woodpaper_count = pd_label['label'].value_counts()['wood,paper']
woodpaper = pd_label[pd_label['label'] == 'wood,paper']
woodpaper_sample = woodpaper.sample(2000,replace=True)
woodpaper_sample
# Out:
#                    filename  item_type       label
# 13003  110_i190_aug2167.png        110  wood,paper
# 286             13_i230.png         13  wood,paper
# 11764   600_i170_aug928.png        600  wood,paper
# 12553  219_i120_aug1717.png        219  wood,paper
# 1927           327_i180.png        327  wood,paper
# ...                     ...        ...         ...
# 10980   321_i230_aug144.png        321  wood,paper
# 7672           990_i150.png        990  wood,paper
# 13225   76_i160_aug2389.png         76  wood,paper
# 6642           867_i170.png        867  wood,paper
# 897            196_i210.png        196  wood,paper
#
# [2000 rows x 3 columns]

# %%
#apply augmentation
for i in range(augment_count):
    img = PIL.Image.open(source_dir+woodpaper_sample.iloc[i]['filename'])
    img = transforms.RandAugment()(img)
    img = transforms_erasing(img)
    img = transforms.ToPILImage()(img)
    item_type = woodpaper_sample.iloc[i]['item_type']
    augname = woodpaper_sample.iloc[i]['filename'][:-4]+'_aug_x' + str(i) + '.png'
    img.save(source_dir+augname)
    #add to csv
    pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# Out:
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_20160\173107524.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)

# %%
#save the upsampled csv
pd_label.to_csv('labels_upsampled.csv',index=False)
