# %% [markdown]
# This piece of code is used to filter to generate the data used for training/testing/validation. We assume we already have a dataset with labels containing the images we needed.

# %%
import numpy as np
import pandas as pd
import os
import shutil
import torchvision.transforms as transforms
import PIL

# %%
#mannually add DataFiltered folder
#see Filter.ipynb in the main directory
#Datafiltered folder contains 12 images with 3 classes 11 of which are transformed using augmentations
#in Datafiltered the plural material classes are removed

# %%
pd_label = pd.read_csv('labelsPlural.csv')
pd_label
# Out:
#           filename  item_type    label
# 0     100_i110.png        100  plastic
# 1     100_i120.png        100  plastic
# 2     100_i130.png        100  plastic
# 3     100_i140.png        100  plastic
# 4     100_i150.png        100  plastic
# ...            ...        ...      ...
# 7747  997_i180.png        997  plastic
# 7748  997_i190.png        997  plastic
# 7749  997_i210.png        997  plastic
# 7750  997_i230.png        997  plastic
# 7751  997_i250.png        997  plastic
#
# [7752 rows x 3 columns]

# %%
#frequency of each class
pd_label['label'].value_counts()
max_count = pd_label['label'].value_counts().max()
max_count
# Out:
# 4548

# %%
source_dir = "./DataFilteredPlural/"

# %%
#upsample metal
#sample metal
metal_count = pd_label['label'].value_counts()['metal']
metal = pd_label[pd_label['label'] == 'metal']
metal_sample = metal.sample(max_count-metal_count,replace=True)
metal_sample
# Out:
#           filename  item_type  label
# 4129  580_i120.png        580  metal
# 6528  855_i110.png        855  metal
# 2888  432_i190.png        432  metal
# 940     2_i150.png          2  metal
# 1258  240_i230.png        240  metal
# ...            ...        ...    ...
# 3790  531_i230.png        531  metal
# 1253  240_i160.png        240  metal
# 3633  517_i210.png        517  metal
# 1705  300_i120.png        300  metal
# 2912  434_i190.png        434  metal
#
# [3084 rows x 3 columns]

# %%
#apply augmentation
for i in range(len(metal_sample)):
    img = PIL.Image.open(source_dir+metal_sample.iloc[i]['filename'])
    img = transforms.RandAugment()(img)
    item_type = metal_sample.iloc[i]['item_type']
    augname = metal_sample.iloc[i]['filename'][:-4]+'_aug' + str(i) + '.png'
    img.save(source_dir+augname)
    #add to csv
    pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# Out:
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# ...
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\3674115339.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)

# %%
#upsample wood,paper
#sample wood,paper
woodpaper_count = pd_label['label'].value_counts()['wood,paper']
woodpaper = pd_label[pd_label['label'] == 'wood,paper']
woodpaper_sample = woodpaper.sample(max_count-woodpaper_count,replace=True)
woodpaper_sample
# Out:
#           filename  item_type       label
# 3244  472_i150.png        472  wood,paper
# 1072  217_i150.png        217  wood,paper
# 314   132_i130.png        132  wood,paper
# 7258   94_i230.png         94  wood,paper
# 1747  303_i180.png        303  wood,paper
# ...            ...        ...         ...
# 912   198_i110.png        198  wood,paper
# 6886  900_i230.png        900  wood,paper
# 214   121_i230.png        121  wood,paper
# 1065  216_i210.png        216  wood,paper
# 6234  825_i170.png        825  wood,paper
#
# [2808 rows x 3 columns]

# %%
#apply augmentation
for i in range(len(woodpaper_sample)):
    img = PIL.Image.open(source_dir+woodpaper_sample.iloc[i]['filename'])
    img = transforms.RandAugment()(img)
    item_type = woodpaper_sample.iloc[i]['item_type']
    augname = woodpaper_sample.iloc[i]['filename'][:-4]+'_aug' + str(i) + '.png'
    img.save(source_dir+augname)
    #add to csv
    pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# Out:
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\2090653968.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)

# %%
#save the upsampled csv
pd_label.to_csv('labels_upsampled.csv',index=False)

# %%
#check the frequency of each class
pd_label['label'].value_counts()
# Out:
# plastic       4548
# wood,paper    4548
# metal         4548
# Name: label, dtype: int64

# %%
#this section augments each class with additional 2000 images per class

# %%
source_dir = "./DataFilteredPlural/"
pd_label = pd.read_csv('./labels_upsampled.csv')
augment_count = 2000

# %%
transforms_erasing = transforms.Compose([transforms.ToTensor(), transforms.RandomErasing( p = 0.3, scale = (0.02, 0.10), ratio = (0.3, 1.0), value = 0, inplace = False)])

# %%
#sample plastic
plastic_count = pd_label['label'].value_counts()['plastic']
plastic = pd_label[pd_label['label'] == 'plastic']
plastic_sample = plastic.sample(2000,replace=True)
plastic_sample
# Out:
#           filename  item_type    label
# 2126  351_i130.png        351  plastic
# 2682  410_i170.png        410  plastic
# 6546  856_i170.png        856  plastic
# 1138  222_i230.png        222  plastic
# 7503  967_i140.png        967  plastic
# ...            ...        ...      ...
# 1587  286_i140.png        286  plastic
# 2398  383_i230.png        383  plastic
# 5960  799_i190.png        799  plastic
# 2713  414_i120.png        414  plastic
# 6699  874_i140.png        874  plastic
#
# [2000 rows x 3 columns]

# %%
#apply augmentation
for i in range(augment_count):
    img = PIL.Image.open(source_dir+plastic_sample.iloc[i]['filename'])
    img = transforms.RandomApply([transforms.RandAugment()], p=0.5)(img)
    img = transforms.RandomRotation(90)(img)
    img = transforms_erasing(img)
    img = transforms.ToPILImage()(img)
    item_type = plastic_sample.iloc[i]['item_type']
    augname = plastic_sample.iloc[i]['filename'][:-4]+'_aug' + str(i) + '.png'
    img.save(source_dir+augname)
    #add to csv
    pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# Out:
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4151560485.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'plastic'},ignore_index=True)

# %%
#sample metal
metal_count = pd_label['label'].value_counts()['metal']
metal = pd_label[pd_label['label'] == 'metal']
metal_sample = metal.sample(2000,replace=True)
metal_sample
# Out:
#                   filename  item_type  label
# 8383   981_i180_aug631.png        981  metal
# 9380  186_i210_aug1628.png        186  metal
# 2471           39_i250.png         39  metal
# 9334  939_i130_aug1582.png        939  metal
# 8945  790_i250_aug1193.png        790  metal
# ...                    ...        ...    ...
# 9159  420_i170_aug1407.png        420  metal
# 1559          279_i250.png        279  metal
# 8407   312_i170_aug655.png        312  metal
# 638           166_i130.png        166  metal
# 9656  673_i140_aug1904.png        673  metal
#
# [2000 rows x 3 columns]

# %%
#apply augmentation
for i in range(augment_count):
    img = PIL.Image.open(source_dir+metal_sample.iloc[i]['filename'])
    img = transforms.RandomApply([transforms.RandAugment()], p=0.5)(img)
    img = transforms.RandomRotation(90)(img)
    img = transforms_erasing(img)
    img = transforms.ToPILImage()(img)
    item_type = metal_sample.iloc[i]['item_type']
    augname = metal_sample.iloc[i]['filename'][:-4]+'_aug_x' + str(i) + '.png'
    img.save(source_dir+augname)
    #add to csv
    pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# Out:
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\53461124.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'metal'},ignore_index=True)

# %%
#sample wood,paper
woodpaper_count = pd_label['label'].value_counts()['wood,paper']
woodpaper = pd_label[pd_label['label'] == 'wood,paper']
woodpaper_sample = woodpaper.sample(2000,replace=True)
woodpaper_sample
# Out:
#                    filename  item_type       label
# 114            110_i170.png        110  wood,paper
# 13385  924_i230_aug2549.png        924  wood,paper
# 3341           485_i160.png        485  wood,paper
# 11354   527_i110_aug518.png        527  wood,paper
# 754            181_i230.png        181  wood,paper
# ...                     ...        ...         ...
# 12297  757_i120_aug1461.png        757  wood,paper
# 110            110_i130.png        110  wood,paper
# 3192           467_i110.png        467  wood,paper
# 12303  363_i160_aug1467.png        363  wood,paper
# 11153    83_i140_aug317.png         83  wood,paper
#
# [2000 rows x 3 columns]

# %%
#apply augmentation
for i in range(augment_count):
    img = PIL.Image.open(source_dir+woodpaper_sample.iloc[i]['filename'])
    img = transforms.RandomApply([transforms.RandAugment()], p=0.5)(img)
    img = transforms.RandomRotation(90)(img)
    img = transforms_erasing(img)
    img = transforms.ToPILImage()(img)
    item_type = woodpaper_sample.iloc[i]['item_type']
    augname = woodpaper_sample.iloc[i]['filename'][:-4]+'_aug_x' + str(i) + '.png'
    img.save(source_dir+augname)
    #add to csv
    pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# Out:
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# ...
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)
# C:\Users\Frank\AppData\Local\Temp\ipykernel_11468\4190782662.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd_label = pd_label.append({'filename':augname, 'item_type': item_type,'label':'wood,paper'},ignore_index=True)

# %%
#save the upsampled csv
pd_label.to_csv('labels_upsampled.csv',index=False)
